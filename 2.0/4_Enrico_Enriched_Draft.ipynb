# %% [markdown]
# #  4_Enrico_Enriched_Draft.ipynb FEATURE ENGINEERING
#
# This notebook logically follows the preprocessing step and performs feature engineering for modeling or further analysis. This will be using the newly cleaned dataset from 3_Enrico_Pre-Processing_Draft.ipynb.
#
# ✔ What it does:
#
# - Loads the cleaned data from the previous step (pre-processed.csv).
#
# Creates new features:
# - Price Change %
# - Target (binary label: will price rise next day?)
# - Date features: weekday, month, quarter
# - Rolling averages (MA_5, MA_10)
# - Daily Return and log of Adjusted Close price

# %%
import pandas as pd
import numpy as np

file_path = "/Users/enricotajanlangit/Desktop/pre-processed.csv" # - ADAPT TO YOUR LOCAL ENVIRONMENT

df_merged = pd.read_csv(file_path)

df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11953125 entries, 0 to 11953124
# Data columns (total 32 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   Ticker                                    object
#  1   Date                                      object
#  2   SimFinId                                  int64
#  3   Open                                      float64
#  4   High                                      float64
#  5   Low                                       float64
#  6   Close                                     float64
#  7   Adj. Close                                float64
#  8   Volume                                    int64
#  9   Shares Outstanding                        float64
#  10  Currency                                  object
#  11  Fiscal Year                               int64
#  12  Fiscal Period                             object
#  13  Publish Date                              object
#  14  Restated Date                             object
#  15  Shares (Basic)                            float64
#  16  Shares (Diluted)                          float64
#  17  Revenue                                   float64
#  18  Cost of Revenue                           float64
#  19  Gross Profit                              float64
#  20  Operating Expenses                        float64
#  21  Selling, General & Administrative         float64
#  22  Operating Income (Loss)                   float64
#  23  Non-Operating Income (Loss)               float64
#  24  Interest Expense, Net                     float64
#  25  Pretax Income (Loss), Adj.                float64
#  26  Abnormal Gains (Losses)                   float64
#  27  Pretax Income (Loss)                      float64
#  28  Income Tax (Expense) Benefit, Net         float64
#  29  Income (Loss) from Continuing Operations  int64
#  30  Net Income                                int64
#  31  Net Income (Common)                       int64
# dtypes: float64(20), int64(6), object(6)
# memory usage: 2.8+ GB

# %%
df_merged.head()
# Out:
#   Ticker        Date  SimFinId   Open   High    Low  Close  Adj. Close  \
# 0      A  2019-04-15     45846  81.00  81.13  79.91  80.40       77.22
# 1   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 2   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 3   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 4   AXSM  2019-04-15  10383750  14.02  14.80  13.62  14.31       14.31
#
#     Volume  Shares Outstanding  ... Operating Income (Loss)  \
# 0  1627268         317515869.0  ...             941000000.0
# 1    24772           7402000.0  ...              44464000.0
# 2    24772           7402000.0  ...              21634000.0
# 3    24772           7402000.0  ...              17191000.0
# 4  1774954          33052468.0  ...            -124707000.0
#
#    Non-Operating Income (Loss) Interest Expense, Net  \
# 0                  -22000000.0           -38000000.0
# 1                   -2682000.0            -2763000.0
# 2                     -13000.0              -39000.0
# 3                    -449000.0              -83000.0
# 4                   -5696000.0            -5696000.0
#
#   Pretax Income (Loss), Adj. Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                919000000.0                     NaN           919000000.0
# 1                 41782000.0            1.093600e+07            52718000.0
# 2                 21621000.0           -4.160000e+05            21205000.0
# 3                 16742000.0           -4.590000e+05            16283000.0
# 4               -130403000.0           -5.674333e+06          -130403000.0
#
#    Income Tax (Expense) Benefit, Net  \
# 0                        152000000.0
# 1                        -10929000.0
# 2                         -5319000.0
# 3                         -2914000.0
# 4                         -3405000.0
#
#    Income (Loss) from Continuing Operations  Net Income  Net Income (Common)
# 0                                1071000000  1071000000           1071000000
# 1                                  41789000    41789000             41789000
# 2                                  15886000    15886000             15886000
# 3                                  13369000    13369000             13369000
# 4                                -130403000  -130403000           -130403000
#
# [5 rows x 32 columns]

# %% [markdown]
# New Columns:
#
# ✅ Price Change % → Added daily price change % calculation (1 day lag)
#
# ✅ Target → Created Target column for market movement prediction
#
# ✅ Weekday (Weekday) → Categorical feature (Monday-Sunday) for classification models.
#
# ✅ Month (Month) → Categorical month number (1-12) for classification models.
#
# ✅ Quarter (Quarter) → Categorical feature (1-4) for classification models.
#
# ✅ Daily Returns (Daily_Return) → Percentage change in adjusted close price, useful for financial modeling.
#
# ✅ Moving Averages (MA_5, MA_10) → 5-day and 10-day moving averages for trend detection.
#
# ✅ Log Transformation (Log_Close) → Helps in normalizing price data for time series models.

# %%
df_merged["Price Change %"] = df_merged["Adj. Close"].pct_change() * 100  # Use correct column name

df_merged.head()
# Out:
#   Ticker        Date  SimFinId   Open   High    Low  Close  Adj. Close  \
# 0      A  2019-04-15     45846  81.00  81.13  79.91  80.40       77.22
# 1   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 2   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 3   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 4   AXSM  2019-04-15  10383750  14.02  14.80  13.62  14.31       14.31
#
#     Volume  Shares Outstanding  ... Non-Operating Income (Loss)  \
# 0  1627268         317515869.0  ...                 -22000000.0
# 1    24772           7402000.0  ...                  -2682000.0
# 2    24772           7402000.0  ...                    -13000.0
# 3    24772           7402000.0  ...                   -449000.0
# 4  1774954          33052468.0  ...                  -5696000.0
#
#    Interest Expense, Net Pretax Income (Loss), Adj. Abnormal Gains (Losses)  \
# 0            -38000000.0                919000000.0                     NaN
# 1             -2763000.0                 41782000.0            1.093600e+07
# 2               -39000.0                 21621000.0           -4.160000e+05
# 3               -83000.0                 16742000.0           -4.590000e+05
# 4             -5696000.0               -130403000.0           -5.674333e+06
#
#   Pretax Income (Loss)  Income Tax (Expense) Benefit, Net  \
# 0          919000000.0                        152000000.0
# 1           52718000.0                        -10929000.0
# 2           21205000.0                         -5319000.0
# 3           16283000.0                         -2914000.0
# 4         -130403000.0                         -3405000.0
#
#    Income (Loss) from Continuing Operations  Net Income  Net Income (Common)  \
# 0                                1071000000  1071000000           1071000000
# 1                                  41789000    41789000             41789000
# 2                                  15886000    15886000             15886000
# 3                                  13369000    13369000             13369000
# 4                                -130403000  -130403000           -130403000
#
#    Price Change %
# 0             NaN
# 1      -53.133903
# 2        0.000000
# 3        0.000000
# 4      -60.458690
#
# [5 rows x 33 columns]

# %% [markdown]
# Create the Target Variable for ML
# To predict whether the price will go up or down, shift the adjusted close price:

# %%
df_merged["Target"] = (df_merged["Adj. Close"].shift(-1) > df_merged["Adj. Close"]).astype(int)  # 1 if price rises, 0 if falls
df_merged.head()
# Out:
#   Ticker        Date  SimFinId   Open   High    Low  Close  Adj. Close  \
# 0      A  2019-04-15     45846  81.00  81.13  79.91  80.40       77.22
# 1   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 2   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 3   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 4   AXSM  2019-04-15  10383750  14.02  14.80  13.62  14.31       14.31
#
#     Volume  Shares Outstanding  ... Interest Expense, Net  \
# 0  1627268         317515869.0  ...           -38000000.0
# 1    24772           7402000.0  ...            -2763000.0
# 2    24772           7402000.0  ...              -39000.0
# 3    24772           7402000.0  ...              -83000.0
# 4  1774954          33052468.0  ...            -5696000.0
#
#    Pretax Income (Loss), Adj. Abnormal Gains (Losses) Pretax Income (Loss)  \
# 0                 919000000.0                     NaN          919000000.0
# 1                  41782000.0            1.093600e+07           52718000.0
# 2                  21621000.0           -4.160000e+05           21205000.0
# 3                  16742000.0           -4.590000e+05           16283000.0
# 4                -130403000.0           -5.674333e+06         -130403000.0
#
#   Income Tax (Expense) Benefit, Net  Income (Loss) from Continuing Operations  \
# 0                       152000000.0                                1071000000
# 1                       -10929000.0                                  41789000
# 2                        -5319000.0                                  15886000
# 3                        -2914000.0                                  13369000
# 4                        -3405000.0                                -130403000
#
#    Net Income  Net Income (Common)  Price Change %  Target
# 0  1071000000           1071000000             NaN       0
# 1    41789000             41789000      -53.133903       0
# 2    15886000             15886000        0.000000       0
# 3    13369000             13369000        0.000000       0
# 4  -130403000           -130403000      -60.458690       1
#
# [5 rows x 34 columns]

# %% [markdown]
# Handling Null Values: Since .pct_change() creates NaN values for the first row, fill them:

# %%
df_merged["Price Change %"].fillna(0, inplace=True)
df_merged["Target"].fillna(0, inplace=True)
df_merged.head()
# Out:
# /var/folders/59/8bbcmw0s2vlgn_2mn51xcwwc0000gn/T/ipykernel_1727/287450061.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_merged["Price Change %"].fillna(0, inplace=True)
# /var/folders/59/8bbcmw0s2vlgn_2mn51xcwwc0000gn/T/ipykernel_1727/287450061.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_merged["Target"].fillna(0, inplace=True)
#   Ticker        Date  SimFinId   Open   High    Low  Close  Adj. Close  \
# 0      A  2019-04-15     45846  81.00  81.13  79.91  80.40       77.22
# 1   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 2   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 3   UFPT  2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 4   AXSM  2019-04-15  10383750  14.02  14.80  13.62  14.31       14.31
#
#     Volume  Shares Outstanding  ... Interest Expense, Net  \
# 0  1627268         317515869.0  ...           -38000000.0
# 1    24772           7402000.0  ...            -2763000.0
# 2    24772           7402000.0  ...              -39000.0
# 3    24772           7402000.0  ...              -83000.0
# 4  1774954          33052468.0  ...            -5696000.0
#
#    Pretax Income (Loss), Adj. Abnormal Gains (Losses) Pretax Income (Loss)  \
# 0                 919000000.0                     NaN          919000000.0
# 1                  41782000.0            1.093600e+07           52718000.0
# 2                  21621000.0           -4.160000e+05           21205000.0
# 3                  16742000.0           -4.590000e+05           16283000.0
# 4                -130403000.0           -5.674333e+06         -130403000.0
#
#   Income Tax (Expense) Benefit, Net  Income (Loss) from Continuing Operations  \
# 0                       152000000.0                                1071000000
# 1                       -10929000.0                                  41789000
# 2                        -5319000.0                                  15886000
# 3                        -2914000.0                                  13369000
# 4                        -3405000.0                                -130403000
#
#    Net Income  Net Income (Common)  Price Change %  Target
# 0  1071000000           1071000000        0.000000       0
# 1    41789000             41789000      -53.133903       0
# 2    15886000             15886000        0.000000       0
# 3    13369000             13369000        0.000000       0
# 4  -130403000           -130403000      -60.458690       1
#
# [5 rows x 34 columns]

# %%
# Set option to display all columns
pd.set_option('display.max_columns', None)

# Show DataFrame info
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11953125 entries, 0 to 11953124
# Data columns (total 34 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   Ticker                                    object
#  1   Date                                      object
#  2   SimFinId                                  int64
#  3   Open                                      float64
#  4   High                                      float64
#  5   Low                                       float64
#  6   Close                                     float64
#  7   Adj. Close                                float64
#  8   Volume                                    int64
#  9   Shares Outstanding                        float64
#  10  Currency                                  object
#  11  Fiscal Year                               int64
#  12  Fiscal Period                             object
#  13  Publish Date                              object
#  14  Restated Date                             object
#  15  Shares (Basic)                            float64
#  16  Shares (Diluted)                          float64
#  17  Revenue                                   float64
#  18  Cost of Revenue                           float64
#  19  Gross Profit                              float64
#  20  Operating Expenses                        float64
#  21  Selling, General & Administrative         float64
#  22  Operating Income (Loss)                   float64
#  23  Non-Operating Income (Loss)               float64
#  24  Interest Expense, Net                     float64
#  25  Pretax Income (Loss), Adj.                float64
#  26  Abnormal Gains (Losses)                   float64
#  27  Pretax Income (Loss)                      float64
#  28  Income Tax (Expense) Benefit, Net         float64
#  29  Income (Loss) from Continuing Operations  int64
#  30  Net Income                                int64
#  31  Net Income (Common)                       int64
#  32  Price Change %                            float64
#  33  Target                                    int64
# dtypes: float64(21), int64(7), object(6)
# memory usage: 3.0+ GB

# %%
df_merged.columns
# Out:
# Index(['Ticker', 'Date', 'SimFinId', 'Open', 'High', 'Low', 'Close',
#        'Adj. Close', 'Volume', 'Shares Outstanding', 'Currency', 'Fiscal Year',
#        'Fiscal Period', 'Publish Date', 'Restated Date', 'Shares (Basic)',
#        'Shares (Diluted)', 'Revenue', 'Cost of Revenue', 'Gross Profit',
#        'Operating Expenses', 'Selling, General & Administrative',
#        'Operating Income (Loss)', 'Non-Operating Income (Loss)',
#        'Interest Expense, Net', 'Pretax Income (Loss), Adj.',
#        'Abnormal Gains (Losses)', 'Pretax Income (Loss)',
#        'Income Tax (Expense) Benefit, Net',
#        'Income (Loss) from Continuing Operations', 'Net Income',
#        'Net Income (Common)', 'Price Change %', 'Target'],
#       dtype='object')

# %% [markdown]
# Weekday column

# %%
df_merged['Date'] = pd.to_datetime(df_merged['Date']) # converting the "Date" column to a Datetime Object (double checking)

# %%
# 1. Weekday (Categorical for Classification)
df_merged['Weekday'] = df_merged['Date'].dt.day_name()  # 'Monday', 'Tuesday', etc.

# %% [markdown]
# Month Column

# %%
# 2. Month (Categorical for Classification)
df_merged['Month'] = df_merged['Date'].dt.month  # 1 (Jan) to 12 (Dec)

# %% [markdown]
# Quarter Column

# %%
# 3. Quarter (Categorical for Classification)
df_merged['Quarter'] = df_merged['Date'].dt.quarter  # 1 to 4

# %% [markdown]
# Daily Returns (Percentage Change)

# %%
df_merged['Daily_Return'] = df_merged['Adj. Close'].pct_change() * 100  # Convert to %

# %% [markdown]
# Moving Averages (5-day and 10-day)

# %%
df_merged['MA_5'] = df_merged['Adj. Close'].rolling(window=5, min_periods=1).mean()
df_merged['MA_10'] = df_merged['Adj. Close'].rolling(window=10, min_periods=1).mean()

# %% [markdown]
# Log Transformation for Time Series Modeling

# %%
df_merged['Log_Close'] = np.log(df_merged['Adj. Close'])  # Log of Adjusted Close Price
df_merged.head()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#   Ticker       Date  SimFinId   Open   High    Low  Close  Adj. Close  \
# 0      A 2019-04-15     45846  81.00  81.13  79.91  80.40       77.22
# 1   UFPT 2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 2   UFPT 2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 3   UFPT 2019-04-15   6767729  36.50  36.82  35.90  36.19       36.19
# 4   AXSM 2019-04-15  10383750  14.02  14.80  13.62  14.31       14.31
#
#     Volume  Shares Outstanding Currency  Fiscal Year Fiscal Period  \
# 0  1627268         317515869.0      USD         2019            FY
# 1    24772           7402000.0      USD         2022            FY
# 2    24772           7402000.0      USD         2021            FY
# 3    24772           7402000.0      USD         2020            FY
# 4  1774954          33052468.0      USD         2021            FY
#
#   Publish Date Restated Date  Shares (Basic)  Shares (Diluted)       Revenue  \
# 0   2019-12-19    2021-12-17     314000000.0       318000000.0  5.163000e+09
# 1   2023-03-16    2025-03-03       7564000.0         7663000.0  3.537920e+08
# 2   2022-03-14    2024-02-29       7524000.0         7615000.0  2.063200e+08
# 3   2021-03-12    2023-03-16       7484000.0         7568000.0  1.793730e+08
# 4   2022-03-01    2024-02-23      37618599.0        37618599.0  7.376710e+08
#
#    Cost of Revenue  Gross Profit  Operating Expenses  \
# 0    -2.358000e+09  2.805000e+09       -1.864000e+09
# 1    -2.635320e+08  9.026000e+07       -4.579600e+07
# 2    -1.552060e+08  5.111400e+07       -2.948000e+07
# 3    -1.346890e+08  4.468400e+07       -2.749300e+07
# 4    -4.399370e+08  3.565870e+08       -1.247070e+08
#
#    Selling, General & Administrative  Operating Income (Loss)  \
# 0                      -1.460000e+09              941000000.0
# 1                      -4.579600e+07               44464000.0
# 2                      -2.948000e+07               21634000.0
# 3                      -2.749300e+07               17191000.0
# 4                      -6.664600e+07             -124707000.0
#
#    Non-Operating Income (Loss)  Interest Expense, Net  \
# 0                  -22000000.0            -38000000.0
# 1                   -2682000.0             -2763000.0
# 2                     -13000.0               -39000.0
# 3                    -449000.0               -83000.0
# 4                   -5696000.0             -5696000.0
#
#    Pretax Income (Loss), Adj.  Abnormal Gains (Losses)  Pretax Income (Loss)  \
# 0                 919000000.0                      NaN           919000000.0
# 1                  41782000.0             1.093600e+07            52718000.0
# 2                  21621000.0            -4.160000e+05            21205000.0
# 3                  16742000.0            -4.590000e+05            16283000.0
# 4                -130403000.0            -5.674333e+06          -130403000.0
#
#    Income Tax (Expense) Benefit, Net  \
# 0                        152000000.0
# 1                        -10929000.0
# 2                         -5319000.0
# 3                         -2914000.0
# 4                         -3405000.0
#
#    Income (Loss) from Continuing Operations  Net Income  Net Income (Common)  \
# 0                                1071000000  1071000000           1071000000
# 1                                  41789000    41789000             41789000
# 2                                  15886000    15886000             15886000
# 3                                  13369000    13369000             13369000
# 4                                -130403000  -130403000           -130403000
#
#    Price Change %  Target Weekday  Month  Quarter  Daily_Return       MA_5  \
# 0        0.000000       0  Monday      4        2           NaN  77.220000
# 1      -53.133903       0  Monday      4        2    -53.133903  56.705000
# 2        0.000000       0  Monday      4        2      0.000000  49.866667
# 3        0.000000       0  Monday      4        2      0.000000  46.447500
# 4      -60.458690       1  Monday      4        2    -60.458690  40.020000
#
#        MA_10  Log_Close
# 0  77.220000   4.346658
# 1  56.705000   3.588783
# 2  49.866667   3.588783
# 3  46.447500   3.588783
# 4  40.020000   2.660959
